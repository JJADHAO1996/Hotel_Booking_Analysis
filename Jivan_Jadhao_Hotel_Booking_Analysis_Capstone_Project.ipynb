# %% [markdown]
# <a href="https://colab.research.google.com/github/JJADHAO1996/Hotel_Booking_Repository/blob/main/Jivan_Jadhao_Hotel_Booking_Analysis_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <b> Have you ever wondered when the best time of year to book a hotel room is? Or the optimal length of stay in order to get the best daily rate? What if you wanted to predict whether or not a hotel was likely to receive a disproportionately high number of special requests? This hotel booking dataset can help you explore those questions!
#
# ## <b>This data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things. All personally identifying information has been removed from the data. </b>
#
# ## <b> Explore and analyze the data to discover important factors that govern the bookings. </b>

# %% [markdown]
# ![768e19844ddb11ecb7a30a58a9feac02.webp](data:image/webp;base64,...)

# %% [markdown]
# At the Inception, we want to import **Pandas** libraries for optimum use in Python, **Matplotlib and Seaborn** for **Data Visualisation** and **Numpy** for Mathematical Analysis. So, Imported packages are as follows

# %%
#import packages
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# Now we have to **Mount** the **Data** which has to be **Analyse**. For mounting process we've to give **Path** of **the Google Drive** where the data is stored. Afterward, We **upload** the file on the colab notebook.

# %%
#mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#uploading csv file from google drive
df=pd.read_csv('/content/drive/MyDrive/Almabetter/Hotel Bookings.csv')

# %% [markdown]
# We can print the Dataframe 'df' which we created.

# %%
#printing the dataframe
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %% [markdown]
# For forther visualisation we need to get thorough information of the datas. Therefore, we get information as follows:

# %%
#getting informaation of the whole data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
#to know shape of the dataframe
df.shape
# Out:
# (119390, 32)

# %% [markdown]
# # **Understanding, Wrangling and Cleaning Data**
# Looking at the dataset we are able to notice some **NaN** values, therefore we need to examine missing values further before continuing with analysis. We can use all the data in one way or the other, but to show **the Data Cleaning** process, We can drop the values of 'Children' as it is smaller in number and marely usefull for an analysis.

# %%
#finding null values
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
#replacing the null values in children column with 0
df.fillna({'children':0},inplace=True)

# %%
#replacing null countries with 'unknown'
df.fillna({'country':'unknown'},inplace=True)

# %%
#check the changes
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               0
# babies                                 0
# meal                                   0
# country                                0
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
#checking the shape after cleaning
df.shape
# Out:
# (119390, 32)

# %% [markdown]
# Henceforth, we would be using this **Cleaned** **Dataframe** for further **Analysis and Visualization**.

# %% [markdown]
# **Magic** **commands** act as convenient functions where Python syntax is not the most natural one. They are useful to embed invalid python syntax in their work flow.

# %%
# line magic can be used as expression and their return value can be assigned to variable. It starts with %.
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %colors  %conda  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %man  %matplotlib  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %shell  %store  %sx  %system  %tb  %tensorflow_version  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %% [markdown]
# **%matplotlib** function activates matplotlib interactive support during an IPython session. However, it does not import matplotlib library.

# %%
# %matplotlib inline

# %% [markdown]
# # **What is the best time of year to book a hotel room ?**

# %%
#creating variable suitable_booking_month
suitable_booking_month=df["arrival_date_month"].value_counts()

# %%
#checking the type of the variable
type(suitable_booking_month)
# Out:
# pandas.core.series.Series

# %%
#sorting the values of the varible
suitable_booking_month.sort_index(inplace=True)

# %%
#print the variable
suitable_booking_month
# Out:
# April        11089
# August       13877
# December      6780
# February      8068
# January       5929
# July         12661
# June         10939
# March         9794
# May          11791
# November      6794
# October      11160
# September    10508
# Name: arrival_date_month, dtype: int64

# %%
#using groupby function to make a group of two data columns from daaframe and store it in new variable
suitable_booking_year1 = df.groupby(['arrival_date_year','arrival_date_month'])['arrival_date_year'].count().unstack()

# %%
#print the new variable
suitable_booking_year1
# Out:
# arrival_date_month   April  August  December  February  January    July  \
# arrival_date_year
# 2015                   NaN  3889.0    2920.0       NaN      NaN  2776.0
# 2016                5428.0  5063.0    3860.0    3891.0   2248.0  4572.0
# 2017                5661.0  4925.0       NaN    4177.0   3681.0  5313.0
#
# arrival_date_month    June   March     May  November  October  September
# arrival_date_year
# 2015                   NaN     NaN     NaN    2340.0   4957.0     5114.0
# 2016                5292.0  4824.0  5478.0    4454.0   6203.0     5394.0
# 2017                5647.0  4970.0  6313.0       NaN      NaN        NaN

# %%
plt.rcParams['figure.figsize'] = (15, 5)

# %%
#plot the graph using matplotlib
plt.figure(figsize = (15,5))
suitable_booking_year1.plot(kind='bar',stacked=False)
plt.title('Monthly Bookings in the year\n2015,2016,2017')
plt.ylabel('Total number of Bookings')
plt.xlabel('Month')
plt.legend()
plt.show()

# %%
# Create the plot object
plt.figure(figsize = (15,5)) # controls size of plot
suitable_booking_month.plot(kind='line')


plt.title('Combined Monthly Booking Traffic of\n2015,2016,2017')
plt.ylabel('Total number of Bookings')
plt.xlabel('Month')
plt.legend() #  shows labels in plot
plt.show()

# %% [markdown]
# **Observation:** In 'Monthly Bookings in the year 2015,2016,2017' bar graphical representation we can easily observed the hike in booking in the month of April, May and October which generally are the vacation period in India. But, In 'Combined Monthly Booking Traffic of n2015,2016,2017', It clearly replicate August month has Highest ever booking traffic. so we can say that Month of August, April, May and October will be suitable month for heavy booking for Hotel Owner. Rest of months should be great for customers to book cause of demand-suppy rule; Less demand high availabality.

# %% [markdown]
# # **Problem:**
# # **How many Customers Confirmed and Canceled the bookings?**

# %%
nctype = [df.reservation_status[df.reservation_status=='Check-Out'].count(),df.reservation_status[df.reservation_status=='Canceled'].count(),df.reservation_status[df.reservation_status=='No-Show'].count()]
ctype = ['Confirmed','Canceled','No-Show']
plt.pie(nctype,labels=ctype,startangle=90,colors=['red','brown','black'], autopct ='%1.1f%%')
plt.show()

# %% [markdown]
# **Observation:** We found that 63% customer have Confirmedt, while 36% customers have Canceled the bookings. And we don't know the preference of 1.0% customres.

# %% [markdown]
# # **Problem:**
# # **Which Group of Family Members Generates a Large Amount of Revenue for Hotels?**

# %% [markdown]
# **Solution:** Here we can show the total spending of each family by creating a column name "family" in existing table with combination of  adults, children and babies column. afterward, we plot a bar plot by adr and family ratio.

# %%
df['family']= df['adults'] + df['children'] + df['babies']
df['family']
# Out:
# 0         2.0
# 1         2.0
# 2         1.0
# 3         1.0
# 4         2.0
#          ...
# 119385    2.0
# 119386    3.0
# 119387    2.0
# 119388    2.0
# 119389    2.0
# Name: family, Length: 119390, dtype: float64

# %%
#change the boolean values into integer in dataframe df
df['family'].astype(int)
# Out:
# 0         2
# 1         2
# 2         1
# 3         1
# 4         2
#          ..
# 119385    2
# 119386    3
# 119387    2
# 119388    2
# 119389    2
# Name: family, Length: 119390, dtype: int64

# %%
plt.rcParams['figure.figsize'] = (15, 5)

# %%
fam = sns.barplot(x=df['family'], y=df['adr'],hue='hotel', data=df, ci=0.01 ,palette='gist_rainbow')
plt.title('Per Capita Revenue Generated from Different Groups of Total Family Members')
sns.set(font_scale = 1)

# %% [markdown]
# **Observation:** From the above Graphical Representation we observe that families having 5 members in total, has the highest amount of spending. This means The City Hotels generally generates a large amount of revenue from families having 5 members in total. Also, we can say that the families which have total members 4 and 5, generally preferred to stay at the City Hotels over the Resort Hotels.

# %% [markdown]
# # **Problem:**
# # **During total stay, which type of meals is consumed by different groups of family members?**

# %%
#creating column name total_stay
df['total_stay']= df['stays_in_weekend_nights'] + df['stays_in_week_nights']

# %%
plt.rcParams['figure.figsize'] = (15, 5)

# %%
plt.figure(figsize=(24,9))
sns.set(style = 'whitegrid')
meal=sns.barplot(x=df.total_stay, y=df.family, hue='meal', data=df, ci=0.01, palette='Set3_r')
plt.title('Meal according to family size')
# Out:
# Text(0.5, 1.0, 'Meal according to family size')

# %% [markdown]
# # **Problem:**
# # **Which is the favourite place to stay in weekend nights for adults?**

# %%
sns.set(style = 'whitegrid')
rr=sns.barplot(df['stays_in_weekend_nights'],df['adults'], hue=df["hotel"], ci=0.01, palette='Set2')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **Observation:**As per above graph, Most of the adults prefer, The Resort Hotels, for Weekend Nights stay. But adults who stay for 10 Weekend Nights are booking The City Hotel over The Resort Hotel.

# %% [markdown]
# # **Problem:**

# %%
# Price distribution box plot
plt.rcParams['figure.figsize'] = (15, 5)
df.groupby(['stays_in_weekend_nights', 'stays_in_week_nights'])['adr'].mean().unstack().plot(kind="box")
#plt.figure(figsize=(15,9))
plt.title('Average Price distribution by Booking Type')
plt.ylabel('Average Prices per Booking')
plt.xlabel('Booking for Week/Weekend Nights')
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))
# Text(0.5, 0, 'Booking for Week/Weekend Nights')

# %% [markdown]
# # Problem:

# %%
park=df.groupby(['required_car_parking_spaces','hotel'])['required_car_parking_spaces'].count().unstack()

# %%
plt.figure(figsize = (15,5))
park.plot(kind='bar')

plt.title('Required Additional Amenities')
plt.ylabel('Hotels')
plt.xlabel('car parkings required')
plt.legend()
plt.show()
